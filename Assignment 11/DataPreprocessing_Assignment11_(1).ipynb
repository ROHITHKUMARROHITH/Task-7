# %%
#Data.csv

# %% [markdown]
# **Step 1: Importing the libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Step 2: Importing dataset**

# %%
df=pd.read_csv("Data.csv")
print(df.shape)
df
# Out:
# (10, 4)
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# **Step 3: Handling the missing data**

# %%
df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#    Country        Age   Salary Purchased
# 0   France  44.000000  72000.0        No
# 1    Spain  27.000000  48000.0       Yes
# 2  Germany  30.000000  54000.0        No
# 3    Spain  38.000000  61000.0        No
# 4  Germany  40.000000      NaN       Yes
# 5   France  35.000000  58000.0       Yes
# 6    Spain  38.777778  52000.0        No
# 7   France  48.000000  79000.0       Yes
# 8  Germany  50.000000  83000.0        No
# 9   France  37.000000  67000.0       Yes

# %%
df['Salary'].describe()
# Out:
# count       10.000000
# mean     63777.777778
# std      11564.099406
# min      48000.000000
# 25%      55000.000000
# 50%      62388.888889
# 75%      70750.000000
# max      83000.000000
# Name: Salary, dtype: float64

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %% [markdown]
# **Step 4: Encoding categorical data**

# %%
df['Purchased'] = df['Purchased'].map({'Yes':1,'No':0})
df
# Out:
#    Country        Age        Salary  Purchased
# 0   France  44.000000  72000.000000          0
# 1    Spain  27.000000  48000.000000          1
# 2  Germany  30.000000  54000.000000          0
# 3    Spain  38.000000  61000.000000          0
# 4  Germany  40.000000  63777.777778          1
# 5   France  35.000000  58000.000000          1
# 6    Spain  38.777778  52000.000000          0
# 7   France  48.000000  79000.000000          1
# 8  Germany  50.000000  83000.000000          0
# 9   France  37.000000  67000.000000          1

# %% [markdown]
# **Step 5: Creating a dummy variable**

# %%
df = pd.get_dummies(df,columns=['Country'])
df
# Out:
#          Age        Salary  Purchased  Country_France  Country_Germany  \
# 0  44.000000  72000.000000          0               1                0
# 1  27.000000  48000.000000          1               0                0
# 2  30.000000  54000.000000          0               0                1
# 3  38.000000  61000.000000          0               0                0
# 4  40.000000  63777.777778          1               0                1
# 5  35.000000  58000.000000          1               1                0
# 6  38.777778  52000.000000          0               0                0
# 7  48.000000  79000.000000          1               1                0
# 8  50.000000  83000.000000          0               0                1
# 9  37.000000  67000.000000          1               1                0
#
#    Country_Spain
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0
# 5              0
# 6              1
# 7              0
# 8              0
# 9              0

# %% [markdown]
# **Step 6: Splitting the datasets into training sets and Test sets**

# %%
x = df.drop(columns='Purchased').values
y = df['Purchased'].values

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=7)

# %%
x_train.shape, y_train.shape
# Out:
# ((8, 5), (8,))

# %%
x_test.shape,y_test.shape
# Out:
# ((2, 5), (2,))

# %% [markdown]
# **Step 7: Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
scaler.transform(x_train)
# Out:
# array([[ 0.96322786,  1.00412676,  1.29099445, -0.57735027, -0.77459667],
#        [-1.22849602, -0.82104614, -0.77459667,  1.73205081, -0.77459667],
#        [-1.69815114, -1.42943711, -0.77459667, -0.57735027,  1.29099445],
#        [-0.13263408,  0.49713428,  1.29099445, -0.57735027, -0.77459667],
#        [ 1.58943468,  1.71391622,  1.29099445, -0.57735027, -0.77459667],
#        [ 0.02391762, -0.11125668, -0.77459667, -0.57735027,  1.29099445],
#        [ 0.14568006, -1.02384313, -0.77459667, -0.57735027,  1.29099445],
#        [ 0.33702103,  0.1704058 , -0.77459667,  1.73205081, -0.77459667]])

# %%
scaler.transform(x_test)
# Out:
# array([[ 1.90253809,  2.1195102 , -0.77459667,  1.73205081, -0.77459667],
#        [-0.4457375 , -0.41545216,  1.29099445, -0.57735027, -0.77459667]])
